# %%
import pandas as pd

# %%
alex = pd.read_csv('./test_set_gpt/alex.csv')
decilm = pd.read_csv('./test_set_gpt/decilm.csv')
merge = pd.merge(alex, decilm, on=['Date', 'Publication', 'Headline', 'URL'], how='left')

# %%
merge.head(5)
# Out:
#        Date      Publication  \
# 0  20131115  Washington Post
# 1  20150504       Daily Mail
# 2  20150219     The Guardian
# 3  20170104              FOX
# 4  20210827   New York Times
#
#                                                                                                                       Headline  \
# 0                                                                              Facebook makes changes to its data use policies
# 1  The 'alien sounds' captured 22 MILES above Earth: Nasa recording from the edge of space has unexplained hisses and whistles
# 2                                                                  Oscars television broadcast set to score record ad revenues
# 3                                              FAKE CYBER WAR'? 'Guccifer' casts doubt on White House's Russian hacking claims
# 4                                                                                              Zeynep TufekciShow Me the Data!
#
#                                                                                                                                                                                                               URL  \
# 0  http://www.washingtonpost.com/business/technology/facebook-makes-changes-to-its-data-use-policies/2013/11/15/0107eab4-4e2f-11e3-be6b-d3d28122e6d4_story.html?tid=hpModule_1728cf4a-8a79-11e2-98d9-3012c1cd8d1e
# 1                                                      http://www.dailymail.co.uk/sciencetech/article-3067819/The-alien-sounds-captured-22-MILES-Earth-Nasa-recording-edge-space-unexplained-hisses-whistles.html
# 2                                                                                                         http://www.theguardian.com/film/2015/feb/19/oscars-television-broadcast-set-to-score-record-ad-revenues
# 3                                                                                             http://www.foxnews.com/politics/2017/01/04/guccifer-casts-doubt-on-obama-administrations-russia-hacking-claims.html
# 4                                                                                                                                             https://www.nytimes.com/2021/08/27/opinion/covid-data-vaccines.html
#
#   BreachMentioned_x CompanyMentioned_x            Unnamed: 6  \
# 0               NaN           Facebook                   NaN
# 1               NaN               NASA                   NaN
# 2               NaN             Oscars                   NaN
# 3               NaN                NaN  guccifer is a person
# 4               NaN                NaN                   NaN
#
#   BreachMentioned_y CompanyMentioned_y
# 0             False           Facebook
# 1             False              False
# 2             False              False
# 3             False         Government
# 4             False              False

# %%
display(merge['BreachMentioned_x'].unique())
display(merge['BreachMentioned_y'].unique())
merge['BreachMentioned_x'] = merge['BreachMentioned_x'] == 'yes'
merge['BreachMentioned_x'] = merge['BreachMentioned_x'].astype(bool)
merge['BreachMentioned_y'] = (merge['BreachMentioned_y'] == "Yes") | (merge['BreachMentioned_y'] == "True")
# Out:
# array([nan, 'yes'], dtype=object)
# array(['False', 'Yes', 'TRUE'], dtype=object)

# %%
merge[merge['BreachMentioned_x'] != merge['BreachMentioned_y']][["Publication", "Headline", "BreachMentioned_x",	"CompanyMentioned_x",	"Unnamed: 6", "BreachMentioned_y","CompanyMentioned_y"]]
# Out:
#          Publication  \
# 19      The Guardian
# 23               FOX
# 46   Washington Post
# 66        Daily Mail
# 73        Daily Mail
# 75      The Guardian
# 84               BBC
# 87              CNBC
# 143  Washington Post
# 150        USA Today
# 151              CNN
# 187  Washington Post
# 191     The Guardian
# 199    New York Post
#
#                                                                                                                                                    Headline  \
# 19                                                                                               Uefa How leaked emails and invoices led to ban from Europe
# 23                                                                                                            Hackers Hit Nigeria Anti-Fraud Agency Website
# 46                                                                                                        GOP Candidate for Minn. Senate Warns of Data Leak
# 66   Was Sony hack carried out by disgruntled ex-staff? Security officials brief FBI that former employees were behind crippling hack - and NOT North Korea
# 73               Hillary's emails WERE backed up to another server - and it may still exist - as the FBI works to figure out how well the data was scrubbed
# 75                                                                                 US condemns China for ‘malicious’ cyberattacks, including Microsoft hack
# 84                                                                                                                        Mobiles become emergency data net
# 87                                                     Leaked Wayfair receipt shows 1,600 mattresses and 100 bunk beds destined for detention camp for kids
# 143                                                                                        Panera’s data breach puts attention on risks of loyalty programs
# 150                                                                                               Bush, Obama, Trump all abuse Presidential Records Act to…
# 151                                                                                                                       Target CEO during data hack quits
# 187                                                             Twitter suspends Guccifer and DCLeaks after Mueller links them to Russian hacking operation
# 191                                                                                    Personal data of a billion Indians sold online for £6, report claims
# 199                                                                                                 US officials 'confident' Russians hacked DNC         :0
#
#      BreachMentioned_x CompanyMentioned_x  \
# 19                True               UEFA
# 23               False                NaN
# 46                True                NaN
# 66                True               Sony
# 73               False                FBI
# 75                True          Microsoft
# 84               False                NaN
# 87                True            Wayfair
# 143               True             Panera
# 150               True             Target
# 151              False                NaN
# 187               True            Twitter
# 191               True                NaN
# 199               True                DNC
#
#                                                                                                                                                      Unnamed: 6  \
# 19                                                                         i said no because they were leaked internal to the company not a user info or emails
# 23                                                                                                                                                          NaN
# 46   I said no on this one because hard to tell from title and the article link is broken. what do you think? could be warning and not a leak that has happened
# 66                                                                        i put sony, fbi and said yes for data breach because its talking abuot the sony hack
# 73                                                                                                                                                          NaN
# 75                                      i said yes for the hack but since its about multiple hacks I could see why it makes sense to say no. what do you think?
# 84                                                                                                                                                          NaN
# 87                                                                                                              I said yes becasue leaked receipts is user info
# 143                                                                                                                                                         NaN
# 150                                                                                                I said yes becasue data hacks mentioned were about user info
# 151                                                                                                                                                         NaN
# 187                                                                                                        guccifer is a person. I said twitter for the company
# 191                                                                                                                                                         NaN
# 199                                                                                                               i said yes becasue was about data breach/hack
#
#      BreachMentioned_y CompanyMentioned_y
# 19               False              False
# 23                True  American Airlines
# 46               False              False
# 66               False               Sony
# 73                True         Government
# 75               False              False
# 84                True       IAB Tech Lab
# 87               False         Government
# 143              False              False
# 150              False              False
# 151               True             Target
# 187              False         Government
# 191              False           Facebook
# 199              False         Government

# %%
headline = merge[merge['BreachMentioned_x'] != merge['BreachMentioned_y']]

# %%
import pandas as pd

# Set maximum column width to None to avoid truncation
pd.set_option('display.max_colwidth', None)


print(headline.iloc[7])
# Out:
# Date                                                                                                                     20190626
# Publication                                                                                                                  CNBC
# Headline                     Leaked Wayfair receipt shows 1,600 mattresses and 100 bunk beds destined for detention camp for kids
# URL                   https://www.cnbc.com/2019/06/26/leaked-wayfair-receipt-shows-beds-destined-for-detention-camp-for-kids.html
# BreachMentioned_x                                                                                                            True
# CompanyMentioned_x                                                                                                        Wayfair
# Unnamed: 6                                                                        I said yes becasue leaked receipts is user info
# BreachMentioned_y                                                                                                           False
# CompanyMentioned_y                                                                                                     Government
# Name: 87, dtype: object
